# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Using cached soupsieve-2.9.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\100 days ml\.venv\lib\site-packages (from beautifulsoup4) (4.16.0)
# Using cached beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# Using cached soupsieve-2.9.2-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#
#    ---------------------------------------- 0/2 [soupsieve]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# Successfully installed beautifulsoup4-4.15.0 soupsieve-2.9.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import requests

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav', headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e6d7e4e73d76635bedbff538bfd0f526&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#         id                                  title  \
# 0  1560520  Batman: Knightfall Part 1: Knightfall
# 1   980431        Avatar Aang: The Last Airbender
# 2  1007757                                Swapped
# 3  1632181                    Accidental Partners
# 4  1621552                        Facing El Chapo
#
#                                             overview release_date  popularity  \
# 0  Arkham Asylum has been destroyed, and all its ...   2026-06-23     82.3541
# 1  Avatar Aang, the world's last Airbender, learn...   2026-07-24     87.8050
# 2  A small woodland creature and a majestic bird,...   2026-05-01     39.4074
# 3  Two women discover they were both scammed by t...   2026-03-12     16.7104
# 4  Two Mexican officers must survive the final ho...   2026-08-21    115.3632
#
#    vote_average  vote_count
# 0         9.174         321
# 1         9.139        1138
# 2         8.869        2182
# 3         8.850         381
# 4         8.810         696

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e6d7e4e73d76635bedbff538bfd0f526&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
